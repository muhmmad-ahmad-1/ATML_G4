# %%
from server import *

# %%
args = Args(aggr_scheme="NEKD_FedAvg_logging",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10,distill_lr=0.001)
serve = NEKD_FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1310
# F1 Score: 0.0994
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1772
# F1 Score: 0.1463
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1988
# F1 Score: 0.1684
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.2129
# F1 Score: 0.1844
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
# ...

# %%
args = Args(aggr_scheme="NEKD_FedSAM_logging",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10,distill_lr=0.001)
serve = NEKD_FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.2239
# F1 Score: 0.1957
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# ...

# %%
args = Args(aggr_scheme="NEKD_FedAvg_Avg_logging",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1438
# F1 Score: 0.0725
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1684
# F1 Score: 0.1014
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.1889
# F1 Score: 0.1380
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.2132
# F1 Score: 0.1812
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
# ...

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_logging",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedSAM_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# Global Aggregation Completed
# Accuracy: 0.2348
# F1 Score: 0.1853
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD Training Started...
# Data iterator reset
# Data iterator reset
# ...

# %%
args = Args(aggr_scheme="FedSAM",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2000
# F1 Score: 0.1646
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2482
# F1 Score: 0.1970
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="FedAvg",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1293
# F1 Score: 0.0850
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1949
# F1 Score: 0.1517
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2210
# F1 Score: 0.1819
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2367
# F1 Score: 0.2045
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2512
# F1 Score: 0.2239
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2649
# F1 Score: 0.2408
# Training Round Complete!
# Training: Round 7 / 15
# ...

# %%
# Ablation
args = Args(aggr_scheme="NEKD_FedAvg_Avg_1",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedAvg_Avg(args)

# %%
serve.run_experiment()

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_1",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedSAM_Avg(args)

# %%
serve.run_experiment()

# %%
args = Args(aggr_scheme="NEKD_FedAvg_Avg_2",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedAvg_Avg(args)

# %%
serve.run_experiment()

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_2",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedSAM_Avg(args)

# %%
serve.run_experiment()
