# %%
from master import *

# %%
args = Args(aggr_scheme="NEKD_SGD",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2742
# F1 Score: 0.2214
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4082
# F1 Score: 0.3490
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5007
# F1 Score: 0.4161
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5951
# F1 Score: 0.5652
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4573
# F1 Score: 0.3958
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4078
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            beta = 1, alpha1 = 0.3, alpha2 = 0.7)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2541
# F1 Score: 0.1674
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2879
# F1 Score: 0.2136
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3585
# F1 Score: 0.3069
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4975
# F1 Score: 0.4477
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5622
# F1 Score: 0.4820
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4196
# ...

# %%
args = Args(aggr_scheme="NEKD_SAM",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            beta = 1, alpha1 = 0.3, alpha2 = 0.7)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2427
# F1 Score: 0.1549
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2958
# F1 Score: 0.2177
# Training Round Complete!
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD_1",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=5,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            beta = 1, alpha1 = 0.3, alpha2 = 0.7)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2719
# F1 Score: 0.1745
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3811
# F1 Score: 0.3223
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3937
# F1 Score: 0.3410
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4883
# F1 Score: 0.4345
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5204
# F1 Score: 0.4623
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5815
# ...

# %%
args = Args(aggr_scheme="NEKD_SAM_1",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2575
# F1 Score: 0.1485
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3401
# F1 Score: 0.2589
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD_1_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=5,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            beta = 1, alpha1 = 0.3, alpha2 = 0.7)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3124
# F1 Score: 0.2299
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4347
# F1 Score: 0.3385
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3709
# F1 Score: 0.3284
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4047
# F1 Score: 0.3364
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3824
# F1 Score: 0.3238
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3508
# ...

# %%
args = Args(aggr_scheme="NEKD_SAM_1_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=5,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            beta = 1, alpha1 = 0.3, alpha2 = 0.7)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2989
# F1 Score: 0.2086
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Structured Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4018
# F1 Score: 0.3183
# Training Round Complete!
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SGD_2",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3390
# F1 Score: 0.2654
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3039
# F1 Score: 0.2246
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4480
# F1 Score: 0.3935
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3731
# F1 Score: 0.3265
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3925
# F1 Score: 0.3379
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3540
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SAM_2",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2326
# F1 Score: 0.1525
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2809
# F1 Score: 0.1858
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SGD_2_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3230
# F1 Score: 0.2472
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3517
# F1 Score: 0.2907
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4672
# F1 Score: 0.4271
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3675
# F1 Score: 0.2950
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5521
# F1 Score: 0.4739
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5623
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SAM_2_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3200
# F1 Score: 0.2386
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5475
# F1 Score: 0.5210
# Training Round Complete!
# Training: Round 3 / 15
# ...
