# %%
from master import *

# %%
args = Args(aggr_scheme="NEKD_SGD__w_noise_logging",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4451
# F1 Score: 0.3924
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4758
# F1 Score: 0.4349
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4907
# F1 Score: 0.4316
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5662
# F1 Score: 0.5380
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5862
# F1 Score: 0.5662
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5542
# ...

# %%
args = Args(aggr_scheme="NEKD_SAM_w_noise_logging",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4066
# F1 Score: 0.3151
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4675
# F1 Score: 0.4379
# Training Round Complete!
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD__w_noise_logging_1",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=1,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2028
# F1 Score: 0.0974
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3208
# F1 Score: 0.2553
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2797
# F1 Score: 0.2168
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3782
# F1 Score: 0.3225
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3578
# F1 Score: 0.2985
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4003
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD__w_noise_logging_2",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=2,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
serve.run_experiment()
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD__w_noise_logging_5",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=5,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
serve.run_experiment()
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD__w_noise_logging_20",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
serve.run_experiment()
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
args = Args(aggr_scheme="NEKD_SGD_1",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2823
# F1 Score: 0.2009
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4209
# F1 Score: 0.3417
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5204
# F1 Score: 0.4598
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5002
# F1 Score: 0.4557
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.6679
# F1 Score: 0.6496
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.6395
# ...

# %%
args = Args(aggr_scheme="NEKD_SAM_1",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4362
# F1 Score: 0.3356
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4971
# F1 Score: 0.4634
# Training Round Complete!
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SGD_random_logging",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3626
# F1 Score: 0.2821
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3940
# F1 Score: 0.3476
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5647
# F1 Score: 0.5450
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4957
# F1 Score: 0.4755
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5962
# F1 Score: 0.5606
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5351
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SAM_random_logging",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001,
            )
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2373
# F1 Score: 0.1377
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\ATML_G4_Project\Gaussian Noise\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2964
# F1 Score: 0.2171
# Training Round Complete!
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SAM_2",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2326
# F1 Score: 0.1525
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2809
# F1 Score: 0.1858
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SGD_2_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SGD(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3230
# F1 Score: 0.2472
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3517
# F1 Score: 0.2907
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.4672
# F1 Score: 0.4271
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3675
# F1 Score: 0.2950
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5521
# F1 Score: 0.4739
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5623
# ...

# %%
args = Args(leader_selection="random",aggr_scheme="NEKD_SAM_2_2",aggregation_mode="client",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_SAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3200
# F1 Score: 0.2386
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Serverless Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.5475
# F1 Score: 0.5210
# Training Round Complete!
# Training: Round 3 / 15
# ...
