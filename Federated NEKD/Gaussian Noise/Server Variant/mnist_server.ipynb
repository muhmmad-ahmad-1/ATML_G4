# %%
from server import *

# %%
args = Args(aggr_scheme="NEKD_FedAvg",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1387
# F1 Score: 0.0751
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1657
# F1 Score: 0.1196
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1834
# F1 Score: 0.1482
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1934
# F1 Score: 0.1538
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1968
# F1 Score: 0.1540
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1981
# ...

# %%
args = Args(aggr_scheme="NEKD_FedSAM",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2217
# F1 Score: 0.1779
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2388
# F1 Score: 0.1893
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="NEKD_FedAvg_aVG",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1188
# F1 Score: 0.0528
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1440
# F1 Score: 0.0992
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1644
# F1 Score: 0.1263
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1746
# F1 Score: 0.1426
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1830
# F1 Score: 0.1513
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1933
# ...

# %%
args = Args(aggr_scheme="NEKD_Fedsam_Avg",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = NEKD_FedSAM_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2311
# F1 Score: 0.2050
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2581
# F1 Score: 0.2331
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="FedSAM",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1986
# F1 Score: 0.1704
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2570
# F1 Score: 0.2264
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="FedAvg",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1300
# F1 Score: 0.0649
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1669
# F1 Score: 0.1198
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1978
# F1 Score: 0.1709
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2297
# F1 Score: 0.2096
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2518
# F1 Score: 0.2299
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2669
# F1 Score: 0.2463
# Training Round Complete!
# Training: Round 7 / 15
# ...

# %%
# Ablation
args = Args(aggr_scheme="NEKD_FedAvg_Avg_1",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1448
# F1 Score: 0.0843
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1709
# F1 Score: 0.1155
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1802
# F1 Score: 0.1250
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1864
# F1 Score: 0.1334
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1890
# F1 Score: 0.1404
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1945
# ...

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_1",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedSAM_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2550
# F1 Score: 0.2144
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2657
# F1 Score: 0.2247
# Training Round Complete!
# Training: Round 3 / 15
# ...

# %%
args = Args(aggr_scheme="NEKD_FedAvg_Avg_2",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_2",dataset="MNIST",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedSAM_Avg(args)

# %%
serve.run_experiment()
