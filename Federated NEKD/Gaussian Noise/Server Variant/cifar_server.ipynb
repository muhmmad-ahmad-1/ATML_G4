# %%
from server import *

# %%
args = Args(aggr_scheme="NEKD_FedAvg",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1771
# F1 Score: 0.1278
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1960
# F1 Score: 0.1451
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2091
# F1 Score: 0.1576
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2135
# F1 Score: 0.1632
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2161
# F1 Score: 0.1651
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2167
# F1 Score: 0.1687
# Training Round Complete!
# Training: Round 7 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2174
# F1 Score: 0.1705
# Training Round Complete!
# Training: Round 8 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2145
# F1 Score: 0.1700
# Training Round Complete!
# Training: Round 9 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2164
# F1 Score: 0.1721
# Training Round Complete!
# Training: Round 10 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2191
# F1 Score: 0.1749
# Training Round Complete!
# Training: Round 11 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2170
# F1 Score: 0.1740
# Training Round Complete!
# Training: Round 12 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2195
# F1 Score: 0.1781
# Training Round Complete!
# Training: Round 13 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2203
# F1 Score: 0.1814
# Training Round Complete!
# Training: Round 14 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2219
# F1 Score: 0.1835
# Training Round Complete!
# Training: Round 15 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2217
# F1 Score: 0.1849
# Training Round Complete!

# %%
args = Args(aggr_scheme="NEKD_FedSAM",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10,distill_lr=0.001)
serve = NEKD_FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2286
# F1 Score: 0.1798
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2572
# F1 Score: 0.2114
# Training Round Complete!
# Training: Round 3 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2702
# F1 Score: 0.2335
# Training Round Complete!
# Training: Round 4 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2827
# F1 Score: 0.2496
# Training Round Complete!
# Training: Round 5 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2874
# F1 Score: 0.2552
# Training Round Complete!
# Training: Round 6 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2972
# F1 Score: 0.2696
# Training Round Complete!
# Training: Round 7 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3044
# F1 Score: 0.2790
# Training Round Complete!
# Training: Round 8 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3078
# F1 Score: 0.2851
# Training Round Complete!
# Training: Round 9 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3084
# F1 Score: 0.2871
# Training Round Complete!
# Training: Round 10 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3105
# F1 Score: 0.2889
# Training Round Complete!
# Training: Round 11 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3129
# F1 Score: 0.2915
# Training Round Complete!
# Training: Round 12 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3097
# F1 Score: 0.2856
# Training Round Complete!
# Training: Round 13 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3084
# F1 Score: 0.2811
# Training Round Complete!
# Training: Round 14 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3093
# F1 Score: 0.2805
# Training Round Complete!
# Training: Round 15 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3083
# F1 Score: 0.2772
# Training Round Complete!

# %%
args = Args(aggr_scheme="NEKD_FedAvg_Avg",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1188
# F1 Score: 0.0528
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1440
# F1 Score: 0.0992
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1644
# F1 Score: 0.1263
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1746
# F1 Score: 0.1426
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1830
# F1 Score: 0.1513
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1933
# F1 Score: 0.1573
# Training Round Complete!
# Training: Round 7 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1986
# F1 Score: 0.1601
# Training Round Complete!
# Training: Round 8 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2021
# F1 Score: 0.1605
# Training Round Complete!
# Training: Round 9 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2027
# F1 Score: 0.1615
# Training Round Complete!
# Training: Round 10 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2059
# F1 Score: 0.1627
# Training Round Complete!
# Training: Round 11 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2055
# F1 Score: 0.1627
# Training Round Complete!
# Training: Round 12 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2046
# F1 Score: 0.1634
# Training Round Complete!
# Training: Round 13 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2075
# F1 Score: 0.1659
# Training Round Complete!
# Training: Round 14 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2034
# F1 Score: 0.1611
# Training Round Complete!
# Training: Round 15 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2034
# F1 Score: 0.1593
# Training Round Complete!

# %%
args = Args(aggr_scheme="NEKD_Fedsam_Avg",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = NEKD_FedSAM_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2311
# F1 Score: 0.2050
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2581
# F1 Score: 0.2331
# Training Round Complete!
# Training: Round 3 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2905
# F1 Score: 0.2756
# Training Round Complete!
# Training: Round 4 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3027
# F1 Score: 0.2919
# Training Round Complete!
# Training: Round 5 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3129
# F1 Score: 0.3020
# Training Round Complete!
# Training: Round 6 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3181
# F1 Score: 0.3071
# Training Round Complete!
# Training: Round 7 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3171
# F1 Score: 0.3034
# Training Round Complete!
# Training: Round 8 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3212
# F1 Score: 0.3057
# Training Round Complete!
# Training: Round 9 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3210
# F1 Score: 0.3024
# Training Round Complete!
# Training: Round 10 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3177
# F1 Score: 0.2963
# Training Round Complete!
# Training: Round 11 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3230
# F1 Score: 0.3005
# Training Round Complete!
# Training: Round 12 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3213
# F1 Score: 0.2963
# Training Round Complete!
# Training: Round 13 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3209
# F1 Score: 0.2936
# Training Round Complete!
# Training: Round 14 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3240
# F1 Score: 0.2963
# Training Round Complete!
# Training: Round 15 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3227
# F1 Score: 0.2937
# Training Round Complete!

# %%
args = Args(aggr_scheme="FedSAM",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1924
# F1 Score: 0.1638
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2474
# F1 Score: 0.2192
# Training Round Complete!
# Training: Round 3 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2723
# F1 Score: 0.2356
# Training Round Complete!
# Training: Round 4 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2958
# F1 Score: 0.2560
# Training Round Complete!
# Training: Round 5 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3113
# F1 Score: 0.2690
# Training Round Complete!
# Training: Round 6 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3209
# F1 Score: 0.2749
# Training Round Complete!
# Training: Round 7 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3270
# F1 Score: 0.2804
# Training Round Complete!
# Training: Round 8 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3369
# F1 Score: 0.2907
# Training Round Complete!
# Training: Round 9 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3465
# F1 Score: 0.3010
# Training Round Complete!
# Training: Round 10 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3533
# F1 Score: 0.3098
# Training Round Complete!
# Training: Round 11 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3624
# F1 Score: 0.3199
# Training Round Complete!
# Training: Round 12 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3713
# F1 Score: 0.3308
# Training Round Complete!
# Training: Round 13 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3828
# F1 Score: 0.3436
# Training Round Complete!
# Training: Round 14 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3915
# F1 Score: 0.3528
# Training Round Complete!
# Training: Round 15 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3991
# F1 Score: 0.3613
# Training Round Complete!

# %%
args = Args(aggr_scheme="FedAvg",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=20,lambd1=0.3,lambd2=0.7,n_clients=10)
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1373
# F1 Score: 0.0926
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1782
# F1 Score: 0.1380
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2022
# F1 Score: 0.1649
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2227
# F1 Score: 0.1883
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2456
# F1 Score: 0.2197
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2693
# F1 Score: 0.2514
# Training Round Complete!
# Training: Round 7 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2908
# F1 Score: 0.2753
# Training Round Complete!
# Training: Round 8 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3045
# F1 Score: 0.2883
# Training Round Complete!
# Training: Round 9 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3123
# F1 Score: 0.2944
# Training Round Complete!
# Training: Round 10 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3175
# F1 Score: 0.2972
# Training Round Complete!
# Training: Round 11 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3240
# F1 Score: 0.3033
# Training Round Complete!
# Training: Round 12 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3308
# F1 Score: 0.3097
# Training Round Complete!
# Training: Round 13 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3354
# F1 Score: 0.3143
# Training Round Complete!
# Training: Round 14 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3377
# F1 Score: 0.3174
# Training Round Complete!
# Training: Round 15 / 15
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3430
# F1 Score: 0.3232
# Training Round Complete!

# %%
# Ablation
args = Args(aggr_scheme="NEKD_FedAvg_Avg_1",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1448
# F1 Score: 0.0843
# Training Round Complete!
# Training: Round 2 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1709
# F1 Score: 0.1155
# Training Round Complete!
# Training: Round 3 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1802
# F1 Score: 0.1250
# Training Round Complete!
# Training: Round 4 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1864
# F1 Score: 0.1334
# Training Round Complete!
# Training: Round 5 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1890
# F1 Score: 0.1404
# Training Round Complete!
# Training: Round 6 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1945
# F1 Score: 0.1488
# Training Round Complete!
# Training: Round 7 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1930
# F1 Score: 0.1491
# Training Round Complete!
# Training: Round 8 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1948
# F1 Score: 0.1530
# Training Round Complete!
# Training: Round 9 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1928
# F1 Score: 0.1520
# Training Round Complete!
# Training: Round 10 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1967
# F1 Score: 0.1558
# Training Round Complete!
# Training: Round 11 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1996
# F1 Score: 0.1592
# Training Round Complete!
# Training: Round 12 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1972
# F1 Score: 0.1559
# Training Round Complete!
# Training: Round 13 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1971
# F1 Score: 0.1544
# Training Round Complete!
# Training: Round 14 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1978
# F1 Score: 0.1559
# Training Round Complete!
# Training: Round 15 / 15
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.1945
# F1 Score: 0.1521
# Training Round Complete!

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_1",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=0,lambd2=1,n_clients=10)
serve = NEKD_FedSAM_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2550
# F1 Score: 0.2144
# Training Round Complete!
# Training: Round 2 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2657
# F1 Score: 0.2247
# Training Round Complete!
# Training: Round 3 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2802
# F1 Score: 0.2521
# Training Round Complete!
# Training: Round 4 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2837
# F1 Score: 0.2578
# Training Round Complete!
# Training: Round 5 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.2909
# F1 Score: 0.2639
# Training Round Complete!
# Training: Round 6 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3000
# F1 Score: 0.2740
# Training Round Complete!
# Training: Round 7 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3053
# F1 Score: 0.2817
# Training Round Complete!
# Training: Round 8 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3120
# F1 Score: 0.2920
# Training Round Complete!
# Training: Round 9 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3137
# F1 Score: 0.2945
# Training Round Complete!
# Training: Round 10 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3162
# F1 Score: 0.2980
# Training Round Complete!
# Training: Round 11 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3148
# F1 Score: 0.2953
# Training Round Complete!
# Training: Round 12 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3228
# F1 Score: 0.3038
# Training Round Complete!
# Training: Round 13 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3253
# F1 Score: 0.3048
# Training Round Complete!
# Training: Round 14 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3234
# F1 Score: 0.3012
# Training Round Complete!
# Training: Round 15 / 15
# f:\Muhammad Ahmad\Server Variant\client\fedsam.py:36: FutureWarning: `torch.nn.utils.clip_grad_norm` is now deprecated in favor of `torch.nn.utils.clip_grad_norm_`.
#   torch.nn.utils.clip_grad_norm(parameters=self.model.parameters(),max_norm=self.max_norm)
# Local Training Completed
#
# NEKD.....
# Global Aggregation Completed
# Accuracy: 0.3200
# F1 Score: 0.2938
# Training Round Complete!

# %%
args = Args(aggr_scheme="NEKD_FedAvg_Avg_2",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedAvg_Avg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.019, 0.086, 0.000, 0.104, 0.000, 0.438, 0.222, 0.001, 0.002, 0.128, Amount:5000
# Client   1: 0.009, 0.006, 0.000, 0.005, 0.410, 0.227, 0.307, 0.001, 0.022, 0.012, Amount:5000
# Client   2: 0.051, 0.030, 0.005, 0.072, 0.280, 0.165, 0.207, 0.106, 0.062, 0.023, Amount:5000
# Client   3: 0.001, 0.047, 0.654, 0.144, 0.000, 0.000, 0.011, 0.000, 0.020, 0.122, Amount:5000
# Client   4: 0.165, 0.100, 0.000, 0.003, 0.304, 0.153, 0.211, 0.000, 0.012, 0.052, Amount:5000
# Client   5: 0.534, 0.300, 0.000, 0.064, 0.000, 0.000, 0.010, 0.032, 0.038, 0.021, Amount:5000
# Client   6: 0.013, 0.038, 0.000, 0.001, 0.000, 0.001, 0.001, 0.654, 0.282, 0.008, Amount:5000
# Client   7: 0.159, 0.293, 0.341, 0.090, 0.000, 0.000, 0.013, 0.040, 0.036, 0.029, Amount:5000
# Client   8: 0.007, 0.004, 0.000, 0.300, 0.000, 0.000, 0.004, 0.056, 0.037, 0.593, Amount:5000
# Client   9: 0.043, 0.096, 0.000, 0.218, 0.005, 0.015, 0.014, 0.110, 0.488, 0.011, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 15
# Local Training Completed
#
# NEKD.....

# %%
args = Args(aggr_scheme="NEKD_FedSAM_Avg_2",dataset="CIFAR10",training_rounds=15,local_epochs=10,rule_arg=0.1,rho=0.01,lambd=0.1,distill_epochs=10,lambd1=1,lambd2=0,n_clients=10)
serve = NEKD_FedSAM_Avg(args)

# %%
serve.run_experiment()
